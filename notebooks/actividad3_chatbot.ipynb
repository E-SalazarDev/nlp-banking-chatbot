# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Proyecto:", PROJECT_ROOT)
print("Python:", sys.executable)
# Out:
# Proyecto: c:\Users\Eduardo\Desktop\Dev\Ejercicios\Bot
# Python: c:\Users\Eduardo\Desktop\Dev\Ejercicios\Bot\.venv\Scripts\python.exe

# %% [markdown]
# ## Pruebas del Chatbot Basado en Reglas
#
# Se ejecutan las pruebas del chatbot basado en reglas utilizando diferentes consultas bancarias
#
# El objetivo es verificar:
#
# - La detección correcta de intenciones
# - La extracción de entidades relevantes
# - El funcionamiento del mecanismo de fallback
# - La generación de respuestas predefinidas para cada intención

# %%
# %run ../tests/pruebas_rule_bot.py
# Out:
# ##########################################################################################
# PRUEBAS DEL CHATBOT BASADO EN REGLAS
# ##########################################################################################
#
# ...
# USUARIO    : Hola
# INTENCIÓN  : saludo
# ENTIDADES  : {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
# ------------------------------------------------------------------------------------------
# RESPUESTA:
# Hola. Soy el asistente virtual bancario. Puedo ayudarte a consultar saldo, solicitar tu estado de cuenta, resolver problemas de acceso o responder dudas generales.
# ...
#
# ...
# USUARIO    : Dame mi saldo bancario
# INTENCIÓN  : consulta_saldo
# ENTIDADES  : {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
# ------------------------------------------------------------------------------------------
# RESPUESTA:
# ...

# %% [markdown]
# ## Pruebas del Chatbot Basado en Modelo de Lenguaje
#
# Se ejecutan diferentes flujos conversacionales para evaluar el comportamiento del chatbot implementado con un modelo de lenguaje
#
# Las pruebas incluyen:
#
# - Solicitud de estado de cuenta
# - Casos de soporte
# - Manejo de contexto conversacional
# - Recuperación después de una consulta fuera del dominio
# - Extracción de entidades adicionales

# %%
# %run ../tests/pruebas_llm_bot.py
# Out:
# ##########################################################################################
# FLUJO 1: CONSULTA DE SALDO
# ##########################################################################################
#
# ...
# USUARIO    : Hola
# INTENCIÓN  : saludo
# ENTIDADES  : {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
#
# RESPUESTA:
# ¡Hola! ¿En qué puedo ayudarte hoy? Puedes revisar tu saldo en "Mis cuentas", donde podrás ver el estado actual de tu cuenta. Si necesitas ayuda con algo más, no dudes en preguntar. ¿Necesitas información sobre cómo acceder a la app o tienes algún problema específico?
#
# CONTEXTO:
#   Intención activa    : saludo
#   Pregunta pendiente  : None
#   Entidades acumuladas: {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
# ...
#
# ...
# USUARIO    : Quiero consultar mi saldo
# INTENCIÓN  : consulta_saldo
# ENTIDADES  : {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
#
# RESPUESTA:
# ...

# %% [markdown]
# ## Comparación entre Ambos Enfoques
#
# En esta sección se comparan las respuestas generadas por:
#
# 1. El chatbot basado en reglas
# 2. El chatbot basado en modelo de lenguaje
#
# La comparación utiliza las mismas entradas para ambos sistemas con el fin de analizar:
#
# - Consistencia en la detección de intenciones
# - Naturalidad de las respuestas
# - Capacidad de adaptación al contexto
# - Diferencias en el comportamiento conversacional

# %%
# %run ../tests/comparacion_bots.py
# Out:
# ########################################################################################################################
# COMPARACIÓN ENTRE CHATBOT BASADO EN REGLAS Y CHATBOT CON LLM
# ########################################################################################################################
#
# ...
# PRUEBA 1
# ENTRADA: Hola
# ------------------------------------------------------------------------------------------------------------------------
# BOT BASADO EN REGLAS
# Intención  : saludo
# Entidades  : {'tipo_cuenta': None, 'monto': None, 'fecha': None, 'tipo_solicitud': None}
# Respuesta  : Hola. Soy el asistente virtual bancario. Puedo ayudarte a consultar saldo, solicitar tu estado de cuenta, resolver problemas de acceso o responder dudas generales.
# ------------------------------------------------------------------------------------------------------------------------
# BOT CON LLM
# Intención  : saludo
# ...
